# %% [markdown]
# ##  Implementing the custom cost function with ruptures format

# %%
from Detection_method import *
from metrics import *
from Data_op import *
from os import listdir
from sklearn import preprocessing
class MyCost(BaseCost):

    """Custom cost for exponential signals."""

    # The 2 following attributes must be specified for compatibility.
    model = "simp"
    min_size = 2

    def fit(self, signal):
        """Set the internal parameter."""
        self.signal = signal
        self.cumsum = np.cumsum(signal,axis=0)
        cumsum1=[0]
        for i in range(signal.shape[0]):
            y=signal[i].reshape((signal.shape[1],1))
            cumsum1.append(cumsum1[i]+y.dot(np.transpose(y)))
        self.cumsum1=cumsum1
            
            
        return self

    def error(self, start, end):
        sub = self.signal[start:end,:]
        mean=1/len(sub)*(self.cumsum[end-2,:]-self.cumsum[max(0,start-1),:])
        term1=1/len(sub)*(self.cumsum1[end-1]-self.cumsum1[start-1])
        term2=mean.dot(np.transpose(mean))
        var=term1-term2
        #var = pd.DataFrame(sub).cov()
        cost=(end-start)*np.linalg.slogdet(var)[1]
        return cost

# %% [markdown]
# ## Running the process on multiple signals

# %%
def process_data(link,method,cost,side):
    print("initiating process for: ",link)
    data=get_side_data(data_acquisition(link),side)
    meta_data=data[1]

    signals=np.asarray(data[0])
    steps=meta_data
    bkps=np.asarray(steps)
    bkps=bkps.reshape(bkps.shape[1]*bkps.shape[0])
    algo = method(custom_cost=cost).fit(signals)
    my_bkps = np.asarray(algo.predict(n_bkps=len(bkps)+1))[1:]
    segs=[]
    detected_steps=[]
    for i in range(len(my_bkps)-1):
        segs.append((my_bkps[i],my_bkps[i+1]))
    limit=np.linalg.norm(data[0].cov())
    for s in segs:
        chunk=data[0].iloc[s[0]:s[1],:]
        x=pd.DataFrame(preprocessing.scale(chunk,with_std=False))
        if(np.linalg.norm(x.cov())>limit):
            detected_steps.append(s)
        
        
    
    return (f_score(detected_steps,steps),detected_steps)


def score_illness(directory,method,cost,side,n_indiv,n_try):
    count_pathology=dict()
    score_pathology=dict()
    scores=dict()
    for i in range(1,n_indiv+1):
        for j in range(1,n_try+1):
        

            file=directory+"\\"+str(i)+"-"+str(j)+".csv"
            if (str(i)+"-"+str(j)+".csv" in listdir(directory)):
                data=data_acquisition(file)
                meta_data=data[1]
                type_illness=meta_data["PathologyGroup"]
                print(type_illness)
                if (not(type_illness in score_pathology)):
                    score_pathology[type_illness]=0
                    count_pathology[type_illness]=0
                
                count_pathology[type_illness]+=1
                res=process_data(file,method,cost,side)
                score_pathology[type_illness]+=res[0]
                scores[file]=res[0]
                print(res[0])
            else:
                break
    for i in score_pathology:
        score_pathology[i]=score_pathology[i]/count_pathology[i]
    return(score_pathology,scores)

results=score_illness("C:\\Users\\Yassine\\Desktop\\GaitData",rpt.BottomUp,MyCost(),'right',50,3)
# Out:
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\1-1.csv
# 0.9322974472807991
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\1-2.csv
# 0.9787234042553191
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\1-3.csv
# 0.9767441860465117
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\2-1.csv
# 0.888888888888889
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\2-2.csv
# 0.9387755102040816
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\2-3.csv
# 0.9361702127659575
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\3-1.csv
# 0.923076923076923
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\3-2.csv
# 0.842911877394636
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\3-3.csv
# 0.8319327731092436
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\4-1.csv
# 0.9714285714285714
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\4-2.csv
# 0.9714285714285714
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\4-3.csv
# 0.9071274298056156
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\5-1.csv
# 0.9279086366880799
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\5-2.csv
# 0.9518599562363238
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\5-3.csv
# 0.9259259259259259
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\6-1.csv
# 0.971830985915493
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\6-2.csv
# 0.9607319862752574
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\6-3.csv
# 0.9776630373779325
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\7-1.csv
# 0.736196319018405
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\8-1.csv
# 0.9302325581395349
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\8-2.csv
# 0.975609756097561
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\8-3.csv
# 0.923076923076923
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\9-1.csv
# 0.909090909090909
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\9-2.csv
# 0.8973607038123168
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\10-1.csv
# 0.9859154929577464
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\10-2.csv
# 0.9577464788732395
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\10-3.csv
# 0.9824561403508771
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\11-1.csv
# 0.8805031446540881
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\11-2.csv
# 0.8289855072463768
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\11-3.csv
# 0.7068273092369478
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\12-1.csv
# 0.962962962962963
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\12-2.csv
# 0.923076923076923
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\12-3.csv
# 0.9258160237388724
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\13-1.csv
# 0.896551724137931
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\13-2.csv
# 0.8516129032258064
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\13-3.csv
# 0.8859060402684563
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\14-1.csv
# 0.9545454545454545
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\14-2.csv
# 0.9302325581395349
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\15-1.csv
# 0.854368932038835
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\15-2.csv
# 0.8571428571428571
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\16-1.csv
# 1.0
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\16-2.csv
# 0.9486823855755894
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\16-3.csv
# 0.9523809523809523
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\17-1.csv
# 0.7058823529411765
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\17-2.csv
# 0.861244019138756
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\17-3.csv
# 0.8135593220338982
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\18-1.csv
# 0.9600000000000001
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\18-2.csv
# 0.8764940239043824
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\18-3.csv
# 0.9166666666666666
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\19-1.csv
# 0.7761194029850746
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\19-2.csv
# 0.7761194029850746
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\19-3.csv
# 0.8704
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\20-1.csv
# 0.9166666666666666
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\20-2.csv
# 0.8695652173913044
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\20-3.csv
# 0.8764940239043824
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\21-1.csv
# 0.9258160237388724
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\21-2.csv
# 0.8730158730158729
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\21-3.csv
# 0.7766990291262137
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\22-1.csv
# 0.9787234042553191
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\22-2.csv
# 0.9565217391304348
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\22-3.csv
# 0.9333333333333333
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\23-1.csv
# 0.9343715239154617
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\23-2.csv
# 0.9411764705882353
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\23-3.csv
# 0.9487179487179488
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\24-1.csv
# 0.8859060402684563
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\24-2.csv
# 0.88
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\24-3.csv
# 0.842911877394636
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\25-1.csv
# 0.962962962962963
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\25-2.csv
# 0.9655172413793104
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\25-3.csv
# 0.8695652173913044
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\26-1.csv
# 0.9375
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\26-2.csv
# 0.9333333333333333
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\27-1.csv
# 0.962962962962963
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\27-2.csv
# 0.9258160237388724
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\27-3.csv
# 0.962962962962963
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\28-1.csv
# 0.9258160237388724
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\28-2.csv
# 0.8450704225352113
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\28-3.csv
# 0.8859060402684563
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\29-1.csv
# 0.826271186440678
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\29-2.csv
# 0.9142857142857143
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\30-1.csv
# 0.9258160237388724
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\30-2.csv
# 0.9258160237388724
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\30-3.csv
# 0.9258160237388724
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\31-1.csv
# 0.9454545454545454
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\31-2.csv
# 0.9252120277563609
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\31-3.csv
# 0.9454545454545454
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\32-1.csv
# 0.9258160237388724
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\32-2.csv
# 0.9258160237388724
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\32-3.csv
# 1.0
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\33-1.csv
# 0.923076923076923
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\33-2.csv
# 0.9258160237388724
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\33-3.csv
# 0.8859060402684563
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\34-1.csv
# 0.9302325581395349
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\34-2.csv
# 0.9302325581395349
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\34-3.csv
# 0.8878504672897196
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\35-1.csv
# 0.8320427236315087
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\35-2.csv
# 0.875886524822695
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\36-1.csv
# 0.9705882352941176
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\36-2.csv
# 0.9508196721311475
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\36-3.csv
# 0.9259259259259259
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\37-1.csv
# 0.9184750733137831
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\37-2.csv
# 0.9560887279311906
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\38-1.csv
# 0.9290953545232273
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\38-2.csv
# 0.9583333333333334
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\38-3.csv
# 0.8825806451612903
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\39-1.csv
# 0.9600000000000001
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\39-2.csv
# 1.0
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\39-3.csv
# 0.9523809523809523
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\40-1.csv
# 0.88
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\40-2.csv
# 0.9655172413793104
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\40-3.csv
# 0.8939828080229226
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\41-1.csv
# 0.9411764705882353
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\41-2.csv
# 0.9714285714285714
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\41-3.csv
# 0.8358208955223881
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\42-1.csv
# 0.8939828080229226
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\42-2.csv
# 0.8250000000000001
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\42-3.csv
# 0.896551724137931
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\43-1.csv
# 0.962962962962963
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\43-2.csv
# 0.9309462915601023
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\43-3.csv
# 0.9285714285714286
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\44-1.csv
# 0.9803921568627451
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\44-2.csv
# 0.9411764705882353
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\44-3.csv
# 1.0
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\45-1.csv
# 0.9591659426585578
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\45-2.csv
# 0.9387755102040816
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\45-3.csv
# 1.0
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\46-1.csv
# 0.9216867469879517
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\46-2.csv
# 0.9500000000000001
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\47-1.csv
# 0.88
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\47-2.csv
# 0.854368932038835
# Orthopedic
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\47-3.csv
# 0.8859060402684563
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\48-1.csv
# 0.9767441860465117
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\48-2.csv
# 0.9322974472807991
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\49-1.csv
# 0.9166666666666666
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\49-2.csv
# 0.9166666666666666
# Healthy
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\49-3.csv
# 0.842911877394636
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\50-1.csv
# 0.9660916121356335
# Neurological
# initiating process for:  C:\Users\Yassine\Desktop\GaitData\50-2.csv
# 0.9629629629629629

# %%
## mean f_score per pathology group
results[0]
# Out:
# {'Neurological': 0.9250046608994347,
#  'Healthy': 0.898978167458605,
#  'Orthopedic': 0.9148263516276608}

# %%
## f_score per signal processed
results[1]
# Out:
# {'C:\\Users\\Yassine\\Desktop\\GaitData\\1-1.csv': 0.9322974472807991,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\1-2.csv': 0.9787234042553191,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\1-3.csv': 0.9767441860465117,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\2-1.csv': 0.888888888888889,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\2-2.csv': 0.9387755102040816,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\2-3.csv': 0.9361702127659575,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\3-1.csv': 0.923076923076923,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\3-2.csv': 0.842911877394636,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\3-3.csv': 0.8319327731092436,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\4-1.csv': 0.9714285714285714,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\4-2.csv': 0.9714285714285714,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\4-3.csv': 0.9071274298056156,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\5-1.csv': 0.9279086366880799,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\5-2.csv': 0.9518599562363238,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\5-3.csv': 0.9259259259259259,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\6-1.csv': 0.971830985915493,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\6-2.csv': 0.9607319862752574,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\6-3.csv': 0.9776630373779325,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\7-1.csv': 0.736196319018405,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\8-1.csv': 0.9302325581395349,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\8-2.csv': 0.975609756097561,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\8-3.csv': 0.923076923076923,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\9-1.csv': 0.909090909090909,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\9-2.csv': 0.8973607038123168,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\10-1.csv': 0.9859154929577464,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\10-2.csv': 0.9577464788732395,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\10-3.csv': 0.9824561403508771,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\11-1.csv': 0.8805031446540881,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\11-2.csv': 0.8289855072463768,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\11-3.csv': 0.7068273092369478,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\12-1.csv': 0.962962962962963,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\12-2.csv': 0.923076923076923,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\12-3.csv': 0.9258160237388724,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\13-1.csv': 0.896551724137931,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\13-2.csv': 0.8516129032258064,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\13-3.csv': 0.8859060402684563,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\14-1.csv': 0.9545454545454545,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\14-2.csv': 0.9302325581395349,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\15-1.csv': 0.854368932038835,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\15-2.csv': 0.8571428571428571,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\16-1.csv': 1.0,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\16-2.csv': 0.9486823855755894,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\16-3.csv': 0.9523809523809523,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\17-1.csv': 0.7058823529411765,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\17-2.csv': 0.861244019138756,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\17-3.csv': 0.8135593220338982,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\18-1.csv': 0.9600000000000001,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\18-2.csv': 0.8764940239043824,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\18-3.csv': 0.9166666666666666,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\19-1.csv': 0.7761194029850746,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\19-2.csv': 0.7761194029850746,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\19-3.csv': 0.8704,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\20-1.csv': 0.9166666666666666,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\20-2.csv': 0.8695652173913044,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\20-3.csv': 0.8764940239043824,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\21-1.csv': 0.9258160237388724,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\21-2.csv': 0.8730158730158729,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\21-3.csv': 0.7766990291262137,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\22-1.csv': 0.9787234042553191,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\22-2.csv': 0.9565217391304348,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\22-3.csv': 0.9333333333333333,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\23-1.csv': 0.9343715239154617,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\23-2.csv': 0.9411764705882353,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\23-3.csv': 0.9487179487179488,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\24-1.csv': 0.8859060402684563,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\24-2.csv': 0.88,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\24-3.csv': 0.842911877394636,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\25-1.csv': 0.962962962962963,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\25-2.csv': 0.9655172413793104,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\25-3.csv': 0.8695652173913044,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\26-1.csv': 0.9375,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\26-2.csv': 0.9333333333333333,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\27-1.csv': 0.962962962962963,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\27-2.csv': 0.9258160237388724,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\27-3.csv': 0.962962962962963,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\28-1.csv': 0.9258160237388724,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\28-2.csv': 0.8450704225352113,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\28-3.csv': 0.8859060402684563,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\29-1.csv': 0.826271186440678,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\29-2.csv': 0.9142857142857143,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\30-1.csv': 0.9258160237388724,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\30-2.csv': 0.9258160237388724,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\30-3.csv': 0.9258160237388724,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\31-1.csv': 0.9454545454545454,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\31-2.csv': 0.9252120277563609,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\31-3.csv': 0.9454545454545454,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\32-1.csv': 0.9258160237388724,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\32-2.csv': 0.9258160237388724,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\32-3.csv': 1.0,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\33-1.csv': 0.923076923076923,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\33-2.csv': 0.9258160237388724,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\33-3.csv': 0.8859060402684563,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\34-1.csv': 0.9302325581395349,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\34-2.csv': 0.9302325581395349,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\34-3.csv': 0.8878504672897196,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\35-1.csv': 0.8320427236315087,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\35-2.csv': 0.875886524822695,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\36-1.csv': 0.9705882352941176,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\36-2.csv': 0.9508196721311475,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\36-3.csv': 0.9259259259259259,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\37-1.csv': 0.9184750733137831,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\37-2.csv': 0.9560887279311906,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\38-1.csv': 0.9290953545232273,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\38-2.csv': 0.9583333333333334,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\38-3.csv': 0.8825806451612903,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\39-1.csv': 0.9600000000000001,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\39-2.csv': 1.0,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\39-3.csv': 0.9523809523809523,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\40-1.csv': 0.88,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\40-2.csv': 0.9655172413793104,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\40-3.csv': 0.8939828080229226,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\41-1.csv': 0.9411764705882353,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\41-2.csv': 0.9714285714285714,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\41-3.csv': 0.8358208955223881,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\42-1.csv': 0.8939828080229226,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\42-2.csv': 0.8250000000000001,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\42-3.csv': 0.896551724137931,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\43-1.csv': 0.962962962962963,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\43-2.csv': 0.9309462915601023,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\43-3.csv': 0.9285714285714286,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\44-1.csv': 0.9803921568627451,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\44-2.csv': 0.9411764705882353,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\44-3.csv': 1.0,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\45-1.csv': 0.9591659426585578,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\45-2.csv': 0.9387755102040816,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\45-3.csv': 1.0,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\46-1.csv': 0.9216867469879517,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\46-2.csv': 0.9500000000000001,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\47-1.csv': 0.88,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\47-2.csv': 0.854368932038835,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\47-3.csv': 0.8859060402684563,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\48-1.csv': 0.9767441860465117,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\48-2.csv': 0.9322974472807991,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\49-1.csv': 0.9166666666666666,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\49-2.csv': 0.9166666666666666,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\49-3.csv': 0.842911877394636,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\50-1.csv': 0.9660916121356335,
#  'C:\\Users\\Yassine\\Desktop\\GaitData\\50-2.csv': 0.9629629629629629}

# %%
## mean f_score
np.asarray([*results[1].values()]).mean()
# Out:
# 0.9150678922856346
